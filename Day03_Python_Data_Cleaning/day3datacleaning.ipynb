# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\titanic data.csv")

# %%
print(df.shape)
print(df.head())
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(round(df.isnull().sum() / len(df) * 100, 2))
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
# Fix Embarked — correct syntax
most_common = df['Embarked'].mode()[0]
print("Most common port:", most_common)

df['Embarked'] = df['Embarked'].fillna(most_common)
print("Embarked missing after fix:", df['Embarked'].isnull().sum())
# Out:
# Most common port: S
# Embarked missing after fix: 0

# %%
median_age=df['Age'].median()
print("median age",median_age)
# Out:
# median age 28.0

# %%
df['Age']=df['Age'].fillna(median_age)
print("Age after fix",df['Age'].isnull().sum())
# Out:
# Age after fix 0

# %%
df=df.drop(columns=['Cabin'])

# %%
print("indextolist",df.columns.tolist())
# Out:
# indextolist ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Embarked']

# %%
print("shape",df.shape)
# Out:
# shape (891, 11)

# %%
# Final data quality check
print("--- FINAL DATA QUALITY REPORT ---")
print("Total rows:", len(df))
print("Total columns:", len(df.columns))
print("Missing values remaining:", df.isnull().sum().sum())
print("\nMissing per column:")
print(df.isnull().sum())
# Out:
# --- FINAL DATA QUALITY REPORT ---
# Total rows: 891
# Total columns: 11
# Missing values remaining: 0
#
# Missing per column:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64
